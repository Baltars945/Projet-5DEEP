# %% [markdown]
# # Projet 5DEEP Apprentissage d'image de paysage

# %%
import sys, json
from pathlib import

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.config import CLASSES, setSeed
from src.evaluate import (
    evaluateModel,
    plotHistory,
    pltConfusionMatrix,
    metricsSummary,
    saveMetrics,
    loadMetrics
    )

    setSeed()
